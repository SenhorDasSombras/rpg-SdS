# %%
from global_var import *

# %%
from DFReader import get_spells_df
from DFFormatAsserter import assert_columns_not_null, fill_na_by_column, assert_df_schema   

spells_df = get_spells_df()
fill_na_by_column(spells_df)
assert_columns_not_null(spells_df)

try:
    assert_df_schema(spells_df)
except ValueError as e:
    print('Wrong values.')
    print(e)
spells_df
# Out:
#                            nome               name  nivel       escola  \
# 0                  Espiro Ácido        Acid Splash      0    elemental
# 1       Proteção contra Lâminas         Blade Ward      0    elemental
# 2             Lâmina Estrondosa      Booming Blade      0    elemental
# 3              Toque Arrepiante        Chill Touch      0  necromancia
# 4              Controlar Chamas     Control Flames      0    elemental
# 5    Criar Fogueira Instantânea     Create Bonfire      0    elemental
# 6                Criar Fogueira     Create Bonfire      0    elemental
# 7                 Globos de Luz     Dancing Lights      0    elemental
# 8                Rajada Mística     Eldritch Blast      0    elemental
# 9                  Raio de Fogo          Fire Bolt      0    elemental
# 10                      Amizade            Friends      0     psíquica
# 11           Mordida Congelante          Frostbite      0    elemental
# 12             Lâmina Elemental  Green-Flame Blade      0    elemental
# 13                   Orientação           Guidance      0    elemental
# 14                       Lufada               Gust      0    elemental
# 15                   Infestação        Infestation      0    invocação
# 16                          Luz              Light      0    elemental
# 17                      Chicote     Lightning Lure      0    elemental
# 18                 Mãos Mágicas          Mage Hand      0  necromancia
# 19              Pedra Encantada        Magic Stone      0    elemental
# 20              Reparo Metálico            Mending      0    elemental
# 21                     Mensagem            Message      0     psíquica
# 22                 Farpa Mental        Mind Sliver      0     psíquica
# 23                 Ilusão Menor      Minor Ilusion      0  ilusionista
# 24                 Moldar Terra         Mold Earth      0    elemental
# 25                  Moldar Água         Mold Water      0    elemental
# 26             Rajada de Veneno       Poison Spray      0    elemental
# 27              Prestidigitação   Prestidigitation      0    elemental
# 28                 Criar Chamas      Produce Flame      0    elemental
# 29                 Raio de Gelo       Ray of Frost      0    elemental
# 30                  Resistência         Resistence      0    elemental
# 31  Ferroada do Enfraquecimento      Sapping Sting      0    elemental
# 32                Chama Sagrada       Secred Flame      0    elemental
# 33               Toque Chocante     Shocking Grasp      0    elemental
# 34               Toque Metálico     Shocking Grasp      0    elemental
# 35                  Estabilizar    Spare the Dying      0    elemental
# 36        Estabilização Musical    Spare the Dying      0      musical
# 37          Rompante de Espadas        Sword Burst      0    elemental
# 38                  Taumaturgia        Thaumaturgy      0  ilusionista
# 39                 Golpe Sonoro        Thunderclap      0      musical
# 40               Soar os Mortos      Toll the Dead      0      musical
# 41              Ataque Certeiro        True Strike      0     psíquica
# 42             Zombaria Viciosa    Vicious Mockery      0      musical
# 43         Palavra do Esplendor   Word of Radiance      0    elemental
#
#     ritual                                          elementos  \
# 0    False                                           [veneno]
# 1    False                           [água, terra, ar, metal]
# 2    False                      [relâmpago, ar, luz, sombras]
# 3    False                                                 []
# 4    False                                    [fogo, sombras]
# 5    False                                             [fogo]
# 6    False                                             [fogo]
# 7    False                                        [luz, fogo]
# 8    False   [água, terra, ar, fogo, luz, sombras, relâmpago]
# 9    False                               [fogo, sombras, luz]
# 10   False                                                 []
# 11   False              [água, terra, veneno, metal, sombras]
# 12   False  [água, terra, fogo, ar, luz, sombras, relâmpag...
# 13   False                                        [luz, água]
# 14   False                  [água, terra, ar, sombras, metal]
# 15   False                                                 []
# 16   False                                              [luz]
# 17   False      [relâmpago, luz, sombras, metal, terra, fogo]
# 18   False                                                 []
# 19   False                                            [terra]
# 20   False                                            [metal]
# 21   False                                                 []
# 22   False                                                 []
# 23   False                                                 []
# 24   False                                            [terra]
# 25   False                                             [água]
# 26   False                           [veneno, sombras, metal]
# 27   False  [água, terra, fogo, ar, sombras, relâmpago, me...
# 28   False                                        [fogo, luz]
# 29   False                              [água, ar, relâmpago]
# 30   False                                        [luz, água]
# 31   False                                          [sombras]
# 32   False                                              [luz]
# 33   False                                        [relâmpago]
# 34   False                                            [metal]
# 35   False                                        [água, luz]
# 36   False                                                 []
# 37   False       [água, terra, ar, fogo, sombras, luz, metal]
# 38   False                                                 []
# 39   False                                                 []
# 40   False                                                 []
# 41   False                                                 []
# 42   False                                                 []
# 43   False                                     [luz, sombras]
#
#    tempo_conjuracao alcance_area  \
# 0            1 ação    18 metros
# 1            1 ação      pessoal
# 2            1 ação      pessoal
# 3            1 ação    36 metros
# 4            1 ação    18 metros
# 5            1 ação    18 metros
# 6            1 ação    18 metros
# 7            1 ação    36 metros
# 8            1 ação    36 metros
# 9            1 ação    36 metros
# 10           1 ação      pessoal
# 11           1 ação    18 metros
# 12           1 ação      pessoal
# 13           1 ação        toque
# 14           1 ação     9 metros
# 15           1 ação     9 metros
# 16           1 ação        toque
# 17           1 ação   4,5 metros
# 18           1 ação     9 metros
# 19     1 ação bonus        toque
# 20         1 minuto        toque
# 21           1 ação    36 metros
# 22           1 ação    18 metros
# 23           1 ação     9 metros
# 24           1 ação     9 metros
# 25           1 ação      pessoal
# 26           1 ação   4,5 metros
# 27           1 ação     3 metros
# 28           1 ação      pessoal
# 29           1 ação    18 metros
# 30           1 ação        toque
# 31           1 ação     9 metros
# 32           1 ação    18 metros
# 33           1 ação        toque
# 34           1 ação        toque
# 35           1 ação        toque
# 36           1 ação   4,5 metros
# 37           1 ação      pessoal
# 38           1 ação     9 metros
# 39           1 ação   4,5 metros
# 40           1 ação    18 metros
# 41           1 ação     9 metros
# 42           1 ação    18 metros
# 43           1 ação   1,5 metros
#
#                                           componentes  mana  \
# 0                                                  VS    50
# 1                                                  VS   100
# 2                    VSM (arma marcial corpo-a-corpo)   100
# 3                                                  VS   100
# 4                                                   S   100
# 5                                                  VS   150
# 6                                                  VS   100
# 7   VSM (um pouco de fósforo ou wychwood ou um ins...    50
# 8                                                  VS   150
# 9                                                  VS   150
# 10           SM (uma pequena quantidade de maquiagem)   100
# 11                                                 VS   100
# 12                SM (uma arma marcial corpo-a-corpo)   200
# 13                                                 VS    75
# 14                                                 VS    50
# 15                               VSM (uma pulga viva)   100
# 16          VSM (um vaga-lume ou musgo fosforescente)   100
# 17                                                 VS   150
# 18                                                 VS   150
# 19                      VSM (um pouco de pó de prata)    50
# 20                                    VSM (dois ímas)   200
# 21              VSM (um pedaço curto de fio de cobre)   100
# 22                                                  V   150
# 23                                VM (um pouco de lã)   100
# 24                                                  S    50
# 25                                                  S    50
# 26                                                 VS   150
# 27                                                 VS    50
# 28                                                 VS    50
# 29                                                 VS   150
# 30                        VSM (um manto em miniatura)    75
# 31                                                 VS   150
# 32                                                 VS   150
# 33                                                 VS   150
# 34                                                 VS   150
# 35                                                 VS   100
# 36                       VSM (um instrumento musical)   150
# 37                      VSM (um pouco de pó de prata)    50
# 38                                                  V    50
# 39                        SM (um instrumento musical)   150
# 40              VSM (um instrumento musical ou canto)   200
# 41                                                  S   100
# 42              VSM (um instrumento musical ou a voz)   100
# 43                                                 VS   150
#
#                        duracao    attack_save dmg_effect          dmg  \
# 0                  instantânea       DEX Save      ácido          1d6
# 1                     1 rodada            N/A        N/A          N/A
# 2                     1 rodada  corpo-a-corpo  elemental          1d8
# 3                     1 rodada            N/A  necrótico          1d8
# 4        instantânea ou 1 hora            N/A        N/A          N/A
# 5                  instantânea       DEX Save       fogo          1d8
# 6   concentração, até 1 minuto       DEX Save       fogo          1d8
# 7   concentração, até 1 minuto            N/A        N/A          N/A
# 8                  instantânea      distância  elemental         1d10
# 9                  instantânea      distância  elemental         1d10
# 10  concentração, até 1 minuto            N/A        N/A          N/A
# 11                 instantânea       CON Save  elemental          1d6
# 12                 instantânea  corpo-a-corpo  elemental          mod
# 13  concentração, até 1 minuto            N/A        N/A          N/A
# 14                 instantânea       STR Save        N/A          N/A
# 15                 instantânea       CON Save     veneno          1d6
# 16    concentração, até 1 hora       DEX Save        N/A          N/A
# 17                 instantânea       STR Save  elemental          1d8
# 18                 instantânea            N/A        N/A          N/A
# 19                    1 minuto      distância  concussão    1d6 + mod
# 20                 instantânea            N/A        N/A          N/A
# 21                    1 rodada            N/A        N/A          N/A
# 22                 instantânea       INT Save   psíquico          1d6
# 23                    1 minuto       INT Test        N/A          N/A
# 24       instantâneo ou 1 hora            N/A        N/A          N/A
# 25       instantânea ou 1 hora            N/A        N/A          N/A
# 26                 instantânea       CON Save  elemental         1d12
# 27                  até 1 hora       DEX Save       fogo          1d6
# 28                  10 minutos      distância       fogo          1d8
# 29                 instantânea      distância  elemental          1d8
# 30  concentração, até 1 minuto            N/A        N/A          N/A
# 31                 instantânea       CON Save  necrótico          1d4
# 32                 instantânea       DEX Save        luz          1d8
# 33                 instantânea            N/A  relâmpago          1d8
# 34                 instantânea            N/A  concussão          1d8
# 35                 instantânea            N/A        N/A          N/A
# 36                 instantânea            N/A        N/A          N/A
# 37                 instantânea       DEX Save       fogo          1d6
# 38                até 1 minuto            N/A        N/A          N/A
# 39                 instantânea       CON Save    energia          1d6
# 40                 instantânea       WIS Save  necrótico  1d8 ou 1d12
# 41                    1 rodada            N/A        N/A          N/A
# 42                 instantânea       WIS Save   psíquico          1d6
# 43                 instantânea       CON Save  elemental          1d6
#
#                                               classes  \
# 0                                      [mago, ladino]
# 1                                       [mago, bardo]
# 2                       [ladino, guerreiro, paladino]
# 3        [mago, bruxo, feiticeiro, guerreiro, ladino]
# 4                           [mago, feiticeiro, bruxo]
# 5              [guerreiro, paladino, ladino, clérigo]
# 6                           [mago, feiticeiro, bruxo]
# 7   [clérigo, paladino, bardo, feiticeiro, mago, l...
# 8   [clérigo, paladino, guerreiro, ladino, monge, ...
# 9   [paladino, ladino, guerreiro, mago, feiticeiro...
# 10  [clérigo, paladino, bardo, mago, bruxo, feitic...
# 11  [clérigo, paladino, ladino, guerreiro, mago, b...
# 12  [clérigo, paladino, mago, bruxo, feiticeiro, l...
# 13  [clérigo, paladino, bardo, bruxo, feiticeiro, ...
# 14    [ladino, mago, feiticeiro, bruxo, bardo, monge]
# 15           [mago, feiticeiro, bruxo, bardo, ladino]
# 16  [clérigo, paladino, ladino, guerreiro, mago, b...
# 17  [clérigo, paladino, bruxo, mago, feiticeiro, m...
# 18  [clérigo, paladino, ladino, guerreiro, monge, ...
# 19  [clérigo, paladino, ladino, guerreiro, bardo, ...
# 20  [clérigo, paladino, guerreiro, mago, feiticeir...
# 21  [clérigo, paladino, mago, feiticeiro, bruxo, l...
# 22  [clérigo, paladino, ladino, guerreiro, bardo, ...
# 23  [clérigo, paladino, bardo, monge, mago, feitic...
# 24  [clérigo, paladino, bardo, monge, ladino, guer...
# 25  [clérigo, paladino, bardo, monge, ladino, guer...
# 26  [clérigo, paladino, guerreiro, ladino, monge, ...
# 27                                [clérigo, paladino]
# 28  [clérigo, paladino, ladino, guerreiro, bardo, ...
# 29  [paladino, ladino, guerreiro, mago, feiticeiro...
# 30  [clérigo, paladino, bardo, bruxo, feiticeiro, ...
# 31  [clérigo, paladino, mago, bruxo, feiticeiro, m...
# 32  [clérigo, paladino, monge, bardo, ladino, guer...
# 33  [clérigo, paladino, ladino, guerreiro, monge, ...
# 34  [clérigo, paladino, ladino, guerreiro, monge, ...
# 35                                [clérigo, paladino]
# 36  [clérigo, paladino, mago, feiticeiro, bruxo, l...
# 37  [clérigo, paladino, monge, ladino, guerreiro, ...
# 38  [clérigo, paladino, bruxo, feiticeiro, mago, l...
# 39  [clérigo, paladino, mago, feiticeiro, bruxo, m...
# 40  [clérigo, paladino, mago, feiticeiro, bruxo, m...
# 41  [clérigo, paladino, guerreiro, ladino, feitice...
# 42  [clérigo, paladino, mago, feiticeiro, bruxo, m...
# 43       [clérigo, paladino, mago, bruxo, feiticeiro]
#
#                                               tags  \
# 0                                           [dano]
# 1                                [defesa, combate]
# 2   [dano, combate, controle, corpo-a-corpo, arma]
# 3                            [dano, corpo-a-corpo]
# 4                            [utilidade, controle]
# 5                                           [dano]
# 6                                 [dano, controle]
# 7                                      [utilidade]
# 8                                [dano, distância]
# 9                                  [dano, combate]
# 10                                          [buff]
# 11                                  [dano, debuff]
# 12                     [dano, corpo-a-corpo, arma]
# 13                                          [buff]
# 14                           [utilidade, controle]
# 15                                [dano, controle]
# 16                                     [utilidade]
# 17            [dano, distância, controle, combate]
# 18                                     [utilidade]
# 19             [dano, toque, utilidade, distância]
# 20                              [toque, utilidade]
# 21                        [utilidade, comunicação]
# 22                               [dano, distância]
# 23                                     [utilidade]
# 24                                      [controle]
# 25                                      [controle]
# 26                               [dano, distância]
# 27                                          [dano]
# 28                    [dano, distância, utilidade]
# 29                                [dano, controle]
# 30                                          [buff]
# 31                                [dano, controle]
# 32                               [dano, distância]
# 33                                   [dano, toque]
# 34                                   [dano, toque]
# 35                               [cura, utilidade]
# 36                               [cura, utilidade]
# 37                                          [dano]
# 38                                     [utilidade]
# 39                                          [dano]
# 40                                          [dano]
# 41                                 [buff, combate]
# 42                                  [dano, debuff]
# 43                                          [dano]
#
#                                             descricao      source  \
# 0   Você arremessa uma bolha de ácido. Escolha uma...         LDJ
# 1   [Ar] Você estende sua mão e traça uma parede d...         LDJ
# 2   Você brande a arma utilizada na conjuração des...       Tasha
# 3   Você cria uma mão esquelética fantasmagórica n...         LDJ
# 4   Você escolhe uma chama não mágica que você pos...    Xanathar
# 5   Você cria uma fogueira no solo em um ponto que...    Xanathar
# 6   Você cria uma fogueira no solo em um ponto que...    Xanathar
# 7   Você cria até quatro luzes do tamanho de tocha...         LDJ
# 8   Um feixe elemental vai em direção a uma criatu...         LDJ
# 9   Você arremessa um cisco elemental em uma criat...         LDJ
# 10  Pela duração, você terá vantagem em todos os t...         LDJ
# 11  Você faz com que um frio entorpecente se forme...    Xanathar
# 12  Você brande a arma utilizada na conjuração des...       Tasha
# 13  Você toca uma criatura voluntária e uma aura e...         LDJ
# 14  Você utiliza seu elemento para causar um dos e...    Xanathar
# 15  Você provoca uma nuvem de ácaros, pulgas e out...    Xanathar
# 16  Você toca um objeto que não tenha mais 3 metro...         LDJ
# 17  Você cria um chicote elemental que golpeia uma...       Tasha
# 18  Uma mão espectral flutuante aparece num ponto,...         LDJ
# 19  Você toca de uma a três pedrinhas e as imbui c...    Xanathar
# 20  Essa magia repara uma única quebra ou fissura ...         LDJ
# 21  Você aponta seu dedo para uma criatura dentro ...         LDJ
# 22  Você direciona um espinho desorientador feito ...       Tasha
# 23  Você cria um som ou uma imagem de um objeto, d...         LDJ
# 24  Você escolhe uma porção de detritos ou pedra q...    Xanathar
# 25  Você escolhe uma área de água que você possa v...    Xanathar
# 26  Você ergue sua mão em direção de uma criatura ...         LDJ
# 27  Essa magia é um truque mágico simples que conj...         LDJ
# 28  Uma chama tremulante aparece na sua mão. A cha...         LDJ
# 29  Um raio elemental parte em direção de uma cria...         LDJ
# 30  Você toca uma criatura voluntária e uma aura e...         LDJ
# 31  Você extrai a vitalidade de uma criatura que v...  Wildemount
# 32  Radiação similar a uma chama desce sobre uma c...         LDJ
# 33  Eletricidade surge da sua mão para transmitir ...         LDJ
# 34  Magnetismo surge da sua mão capaz de alterar u...         LDJ
# 35  Você toca uma criatura viva que esteja com 0 p...         LDJ
# 36  Você toca seu instrumento de forma mágica e el...         LDJ
# 37  Você cria um círculo momentâneo de lâminas ele...       Tasha
# 38  Você manifesta pequenas maravilhas dentro do a...         LDJ
# 39  Você cria uma violenta explosão sonora, que po...    Xanathar
# 40  Você toca uma melodia agoniante que preenche o...    Xanathar
# 41  Você encara um alvo no alcance, vasculhando se...         LDJ
# 42  Você lança uma série de notas dissonantes atad...         LDJ
# 43  Você levanta sua mão para o alto, pronunciando...    Xanathar
#
#    mana_adicional
# 0             N/A
# 1             N/A
# 2             N/A
# 3             N/A
# 4             N/A
# 5             N/A
# 6             N/A
# 7             N/A
# 8             N/A
# 9             N/A
# 10            N/A
# 11            N/A
# 12            N/A
# 13   50 por turno
# 14            N/A
# 15            N/A
# 16            N/A
# 17            N/A
# 18            N/A
# 19            N/A
# 20            N/A
# 21            N/A
# 22            N/A
# 23            N/A
# 24            N/A
# 25            N/A
# 26            N/A
# 27            N/A
# 28            N/A
# 29            N/A
# 30   50 por turno
# 31            N/A
# 32            N/A
# 33            N/A
# 34            N/A
# 35            N/A
# 36            N/A
# 37            N/A
# 38   25 por turno
# 39            N/A
# 40            N/A
# 41            N/A
# 42            N/A
# 43            N/A

# %%
from DFFilter import filter_df

my_filter = {
    'elementos': 'água',
}
filtered_df = filter_df(spells_df, my_filter)

# %%
filtered_df
# Out:
#                        nome               name  nivel     escola  ritual  \
# 1   Proteção contra Lâminas         Blade Ward      0  elemental   False
# 8            Rajada Mística     Eldritch Blast      0  elemental   False
# 11       Mordida Congelante          Frostbite      0  elemental   False
# 12         Lâmina Elemental  Green-Flame Blade      0  elemental   False
# 13               Orientação           Guidance      0  elemental   False
# 14                   Lufada               Gust      0  elemental   False
# 25              Moldar Água         Mold Water      0  elemental   False
# 27          Prestidigitação   Prestidigitation      0  elemental   False
# 29             Raio de Gelo       Ray of Frost      0  elemental   False
# 30              Resistência         Resistence      0  elemental   False
# 35              Estabilizar    Spare the Dying      0  elemental   False
# 37      Rompante de Espadas        Sword Burst      0  elemental   False
#
#                                             elementos tempo_conjuracao  \
# 1                            [água, terra, ar, metal]           1 ação
# 8    [água, terra, ar, fogo, luz, sombras, relâmpago]           1 ação
# 11              [água, terra, veneno, metal, sombras]           1 ação
# 12  [água, terra, fogo, ar, luz, sombras, relâmpag...           1 ação
# 13                                        [luz, água]           1 ação
# 14                  [água, terra, ar, sombras, metal]           1 ação
# 25                                             [água]           1 ação
# 27  [água, terra, fogo, ar, sombras, relâmpago, me...           1 ação
# 29                              [água, ar, relâmpago]           1 ação
# 30                                        [luz, água]           1 ação
# 35                                        [água, luz]           1 ação
# 37       [água, terra, ar, fogo, sombras, luz, metal]           1 ação
#
#    alcance_area                          componentes  mana  \
# 1       pessoal                                   VS   100
# 8     36 metros                                   VS   150
# 11    18 metros                                   VS   100
# 12      pessoal  SM (uma arma marcial corpo-a-corpo)   200
# 13        toque                                   VS    75
# 14     9 metros                                   VS    50
# 25      pessoal                                    S    50
# 27     3 metros                                   VS    50
# 29    18 metros                                   VS   150
# 30        toque          VSM (um manto em miniatura)    75
# 35        toque                                   VS   100
# 37      pessoal        VSM (um pouco de pó de prata)    50
#
#                        duracao    attack_save dmg_effect   dmg  \
# 1                     1 rodada            N/A        N/A   N/A
# 8                  instantânea      distância  elemental  1d10
# 11                 instantânea       CON Save  elemental   1d6
# 12                 instantânea  corpo-a-corpo  elemental   mod
# 13  concentração, até 1 minuto            N/A        N/A   N/A
# 14                 instantânea       STR Save        N/A   N/A
# 25       instantânea ou 1 hora            N/A        N/A   N/A
# 27                  até 1 hora       DEX Save       fogo   1d6
# 29                 instantânea      distância  elemental   1d8
# 30  concentração, até 1 minuto            N/A        N/A   N/A
# 35                 instantânea            N/A        N/A   N/A
# 37                 instantânea       DEX Save       fogo   1d6
#
#                                               classes  \
# 1                                       [mago, bardo]
# 8   [clérigo, paladino, guerreiro, ladino, monge, ...
# 11  [clérigo, paladino, ladino, guerreiro, mago, b...
# 12  [clérigo, paladino, mago, bruxo, feiticeiro, l...
# 13  [clérigo, paladino, bardo, bruxo, feiticeiro, ...
# 14    [ladino, mago, feiticeiro, bruxo, bardo, monge]
# 25  [clérigo, paladino, bardo, monge, ladino, guer...
# 27                                [clérigo, paladino]
# 29  [paladino, ladino, guerreiro, mago, feiticeiro...
# 30  [clérigo, paladino, bardo, bruxo, feiticeiro, ...
# 35                                [clérigo, paladino]
# 37  [clérigo, paladino, monge, ladino, guerreiro, ...
#
#                            tags  \
# 1             [defesa, combate]
# 8             [dano, distância]
# 11               [dano, debuff]
# 12  [dano, corpo-a-corpo, arma]
# 13                       [buff]
# 14        [utilidade, controle]
# 25                   [controle]
# 27                       [dano]
# 29             [dano, controle]
# 30                       [buff]
# 35            [cura, utilidade]
# 37                       [dano]
#
#                                             descricao    source mana_adicional
# 1   [Ar] Você estende sua mão e traça uma parede d...       LDJ            N/A
# 8   Um feixe elemental vai em direção a uma criatu...       LDJ            N/A
# 11  Você faz com que um frio entorpecente se forme...  Xanathar            N/A
# 12  Você brande a arma utilizada na conjuração des...     Tasha            N/A
# 13  Você toca uma criatura voluntária e uma aura e...       LDJ   50 por turno
# 14  Você utiliza seu elemento para causar um dos e...  Xanathar            N/A
# 25  Você escolhe uma área de água que você possa v...  Xanathar            N/A
# 27  Essa magia é um truque mágico simples que conj...       LDJ            N/A
# 29  Um raio elemental parte em direção de uma cria...       LDJ            N/A
# 30  Você toca uma criatura voluntária e uma aura e...       LDJ   50 por turno
# 35  Você toca uma criatura viva que esteja com 0 p...       LDJ            N/A
# 37  Você cria um círculo momentâneo de lâminas ele...     Tasha            N/A

# %%
from IPython.display import Markdown, display
import re
import numpy as np


def get_styled_str(string, color=None, size=None):
    string = string.replace('\n', '<br>').replace('\t', '&emsp;')
    string = f"<span style='color:{color};font-size:{size}'>{string}</span>"
    return string

def printmd(strings):
    string = ""  
    for s in strings:
        string += s
    display(Markdown(string))

def get_lvl_str(spell_series):
    lvl_str = f' lvl {spell_series.nivel}' if spell_series.nivel > 0 else ' - truque'
    return lvl_str

def get_ritual_str(spell_series):
    ritual_str = ' - ritual' if spell_series.ritual else ''
    return ritual_str

def get_escola_str(spell_series):
    if spell_series.escola != 'elemental':
        return ""
    
    elemental_str = ''
    for element in spell_series.elementos[:-1]:
        elemental_str += f'{element}, '
    elemental_str += f'{spell_series.elementos[-1]}'
    elemental_str = f'(_{elemental_str}_)'

    escola_str = f'**{spell_series.escola}** {elemental_str}'
    return escola_str

def get_componentes_str(spell_series):
    componentes_str: str
    regex_match = re.search(r'\(.+\)', spell_series.componentes)
    if regex_match is None:
        componentes_str = f'**{spell_series.componentes}**'
    else:
        componentes_str = f"**{spell_series.componentes.split(' ')[0]}** _{regex_match.group(0)}_"
    return componentes_str

def get_mana_str(spell_series):
    mana_str: str
    if spell_series['mana_adicional'] == 'N/A':
        mana_str = f'**{spell_series.mana}**'
    else:
        mana_str = f'**{spell_series.mana}** (_+ {spell_series.mana_adicional}_)'
    return mana_str

def print_spell(spell_series):
    lvl_str = get_lvl_str(spell_series)
    ritual_str = get_ritual_str(spell_series)
    escola_str = get_escola_str(spell_series)
    componentes_str = get_componentes_str(spell_series)
    mana_str = get_mana_str(spell_series)
    source_str = f"_{spell_series.source}_"

    name_str = f"**{spell_series['nome']} _({spell_series['name']})_**{lvl_str}{ritual_str}\n"

    header_str = f"\tEscola: {escola_str}\n"
    header_str += f"\tTempo conjuração: **{spell_series.tempo_conjuracao}**\n"
    header_str += f"\tAlcance: **{spell_series.alcance_area}**\n"
    header_str += f"\tComponentes: {componentes_str}\n"
    header_str += f"\tMana: {mana_str}\n"
    header_str += f"\tDuração: **{spell_series.duracao}**\n"
    if spell_series.dmg != "N/A":
        header_str += f"\tDano: **{spell_series.dmg}**\n"
    if spell_series.attack_save != "N/A":
        header_str += f"\tAttack/Save: **{spell_series.attack_save}**\n"
    if spell_series.dmg_effect != "N/A":
        header_str += f"\tDmg effect: **{spell_series.dmg_effect}**\n"

    name_str = get_styled_str(name_str)
    header_str = get_styled_str(header_str, size='13px')
    desc_str = get_styled_str(f'{spell_series.descricao}\n')
    source_str = get_styled_str(source_str, color='gray', size='10px')
    printmd([name_str, header_str, desc_str, source_str])

# %%
def print_spells_for_df(df):
    for _, row in df.iterrows():
        print_spell(row)
        print()

# %% [markdown]
# **helo**

# %%
print_spells_for_df(filtered_df)
# Out:
# <span style='color:None;font-size:None'>**Proteção contra Lâminas _(Blade Ward)_** - truque<br></span><span style='color:None;font-size:13px'>&emsp;Escola: **elemental** (_água, terra, ar, metal_)<br>&emsp;Tempo conjuração: **1 ação**<br>&emsp;Alcance: **pessoal**<br>&emsp;Componentes: **VS**<br>&emsp;Mana: **100**<br>&emsp;Duração: **1 rodada**<br></span><span style='color:None;font-size:None'>[Ar] Você estende sua mão e traça uma parede de vento que te protege.<br>[Água] Você cria um fluxo de água ao seu redor, protegendo sua pele de lâminas.<br>[Terra] Você torna sua pele mais resistente, como uma rocha.<br>[Metal] Você torna sua pele mais resistente, como metal.<br><br>&emsp;Até seu próximo turno, você tem resistência contra dano de concussão, cortante e perfurante de ataques com armas.<br></span><span style='color:gray;font-size:10px'>_LDJ_</span>
# <span style='color:None;font-size:None'>**Rajada Mística _(Eldritch Blast)_** - truque<br></span><span style='color:None;font-size:13px'>&emsp;Escola: **elemental** (_água, terra, ar, fogo, luz, sombras, relâmpago_)<br>&emsp;Tempo conjuração: **1 ação**<br>&emsp;Alcance: **36 metros**<br>&emsp;Componentes: **VS**<br>&emsp;Mana: **150**<br>&emsp;Duração: **instantânea**<br>&emsp;Dano: **1d10**<br>&emsp;Attack/Save: **distância**<br>&emsp;Dmg effect: **elemental**<br></span><span style='color:None;font-size:None'>Um feixe elemental vai em direção a uma criatura dentro do alcance. Realize uma jogada de ataque à distância com magia contra o alvo. Se atingir, o alvo sofre 1d10 de dano do seu elemento.<br>&emsp;Caso você utilize apenas uma mão para fazer o ataque, o dano cai pela metade.<br>&emsp;A magia cria mais de um feixe quando você alcança níveis elevados: dois feixes no 5° nível, três feixes no 11° nível e quatro feixes no 17° nível. Você pode direcionar os feixes para o mesmo alvo ou para alvos diferentes. Realize jogadas de ataque separadas para cada feixe.<br></span><span style='color:gray;font-size:10px'>_LDJ_</span>
# <span style='color:None;font-size:None'>**Mordida Congelante _(Frostbite)_** - truque<br></span><span style='color:None;font-size:13px'>&emsp;Escola: **elemental** (_água, terra, veneno, metal, sombras_)<br>&emsp;Tempo conjuração: **1 ação**<br>&emsp;Alcance: **18 metros**<br>&emsp;Componentes: **VS**<br>&emsp;Mana: **100**<br>&emsp;Duração: **instantânea**<br>&emsp;Dano: **1d6**<br>&emsp;Attack/Save: **CON Save**<br>&emsp;Dmg effect: **elemental**<br></span><span style='color:None;font-size:None'>Você faz com que um frio entorpecente se forme em uma criatura que você possa ver, dentro do alcance. O alvo deve realizar um teste de resistência de Constituição. Se falhar na resistência, o alvo sofre 1d6 de dano elemental e terá desvantagem na próxima jogada de ataque com arma que fizer antes do final do seu próximo turno.<br>&emsp;O dano da magia aumenta em 1d6 quando você alcança o 5º nível (2d6), 11 º nível (3d6) e 17º nível (4d6). <br></span><span style='color:gray;font-size:10px'>_Xanathar_</span>
# <span style='color:None;font-size:None'>**Lâmina Elemental _(Green-Flame Blade)_** - truque<br></span><span style='color:None;font-size:13px'>&emsp;Escola: **elemental** (_água, terra, fogo, ar, luz, sombras, relâmpago, metal, veneno_)<br>&emsp;Tempo conjuração: **1 ação**<br>&emsp;Alcance: **pessoal**<br>&emsp;Componentes: **SM** _(uma arma marcial corpo-a-corpo)_<br>&emsp;Mana: **200**<br>&emsp;Duração: **instantânea**<br>&emsp;Dano: **mod**<br>&emsp;Attack/Save: **corpo-a-corpo**<br>&emsp;Dmg effect: **elemental**<br></span><span style='color:None;font-size:None'>Você brande a arma utilizada na conjuração dessa magia e faz um ataque corpo a corpo contra uma criatura a té 1,5m de você. Em um acerto, o alvo sofre os efeitos normais do ataque da arma e você faz com que uma rajada elemental salte do alvo para uma criatura diferente a sua escolha que você possa ver a até 1,5m do primeiro alvo. A segunda criatura sofre dano elemental igual ao seu modificador de atributo de conjuração.<br>&emsp;O dano dessa magia aumenta quando você alcança certos níveis. No 5º nível, o ataque corpo a corpo provoca 1d8 de dano elemental adicional se acertar, e o dano elemental que a segunda criatura recebe aumenta para 1d8 + o modificador de seu atributo de conjuração. Ambos os danos aumentam em 1d8 no 11º nível (2d8 e 2d8) e novamente no 17º nível (3d8 e 3d8).<br></span><span style='color:gray;font-size:10px'>_Tasha_</span>
# <span style='color:None;font-size:None'>**Orientação _(Guidance)_** - truque<br></span><span style='color:None;font-size:13px'>&emsp;Escola: **elemental** (_luz, água_)<br>&emsp;Tempo conjuração: **1 ação**<br>&emsp;Alcance: **toque**<br>&emsp;Componentes: **VS**<br>&emsp;Mana: **75** (_+ 50 por turno_)<br>&emsp;Duração: **concentração, até 1 minuto**<br></span><span style='color:None;font-size:None'>Você toca uma criatura voluntária e uma aura elemental envolve ela, desaparecendo após alguns segundos. Uma vez, antes da magia acabar, o alvo pode rolar 1d4 e adicionar o número rolado a um teste de habilidade a escolha dele. Ele pode rolar o dado antes ou depois de realizar o teste de habilidade. Após isso, a magia termina. Você gasta 50 de mana por turno até o final da magia.<br></span><span style='color:gray;font-size:10px'>_LDJ_</span>
# <span style='color:None;font-size:None'>**Lufada _(Gust)_** - truque<br></span><span style='color:None;font-size:13px'>&emsp;Escola: **elemental** (_água, terra, ar, sombras, metal_)<br>&emsp;Tempo conjuração: **1 ação**<br>&emsp;Alcance: **9 metros**<br>&emsp;Componentes: **VS**<br>&emsp;Mana: **50**<br>&emsp;Duração: **instantânea**<br>&emsp;Attack/Save: **STR Save**<br></span><span style='color:None;font-size:None'>Você utiliza seu elemento para causar um dos efeitos em um ponto que você pode ver dentro do alcance:<br>&emsp;• Uma criatura Média ou menor que você escolher deve ser bem sucedido num teste de resistência de Força ou será afastada 1,5 metros de você.<br>&emsp;• Você cria uma pequena rajada elemental capaz de mover um objeto que não esteja sendo segurado nem carregado e que não pese mais de 2,5 quilos. O objeto é afastado 3 metros de você. Ele não é empurrado com força suficiente para causar dano.<br>&emsp;• [Ar] Você cria um efeito sensorial inofensível usando o ar, como fazer folhas farfalharem, ventos fecharem persianas, suas roupas balançarem com uma brisa.<br>&emsp;• [Sombras] Você cria um efeito sensorial inofensível usando as sombras, como deixar sua sombra maior, diminuir um pouco a luz do ambiente, fazer a sombra de alguém sumir ou criar uma sombra que pode distrair alguém.<br>&emsp;• [Terra] Você cria um efeito sensorial inofensível usando terra, como fazer um pequeno morrinho, um leve tremor capaz de desbalancear um pequeno objeto ou assustar alguém.<br>&emsp;• [Metal] Você cria um efeito sensorial inofensível como esquentar ou deformar levemente um metal.<br></span><span style='color:gray;font-size:10px'>_Xanathar_</span>
# <span style='color:None;font-size:None'>**Moldar Água _(Mold Water)_** - truque<br></span><span style='color:None;font-size:13px'>&emsp;Escola: **elemental** (_água_)<br>&emsp;Tempo conjuração: **1 ação**<br>&emsp;Alcance: **pessoal**<br>&emsp;Componentes: **S**<br>&emsp;Mana: **50**<br>&emsp;Duração: **instantânea ou 1 hora**<br></span><span style='color:None;font-size:None'>Você escolhe uma área de água que você possa ver, dentro do alcance, e que caiba num cubo de 1,5 metros. Você manipula-a de uma das seguintes maneiras:<br>&emsp;• Você move instantaneamente ou, de alguma outra forma, muda o curso da água como você ordenar, até 1,5 metros em qualquer direção. Esse movimento não tem força suficiente para causar dano.<br>&emsp;• Você faz com que a água forme formas simples e se anime como você ordenar. Essa mudança dura por 1 hora.<br>&emsp;• Você muda a cor ou opacidade da água. A água deve ser modificada da mesma forma por inteiro. Essa mudança dura por 1 hora.<br>&emsp;• Você congela a água, considerando que não haja criaturas nela. A água descongela em 1 hora.<br>&emsp;Se você conjurar essa magia diversas vezes, você pode ter atê dois dos seus efeitos não instantâneos ativos ao mesmo tempo, e você pode dissipar um efeito desses com uma ação.<br>&emsp;Essa magia gasta 5 de mana a cada 5 minutos.<br></span><span style='color:gray;font-size:10px'>_Xanathar_</span>
# <span style='color:None;font-size:None'>**Prestidigitação _(Prestidigitation)_** - truque<br></span><span style='color:None;font-size:13px'>&emsp;Escola: **elemental** (_água, terra, fogo, ar, sombras, relâmpago, metal, veneno_)<br>&emsp;Tempo conjuração: **1 ação**<br>&emsp;Alcance: **3 metros**<br>&emsp;Componentes: **VS**<br>&emsp;Mana: **50**<br>&emsp;Duração: **até 1 hora**<br>&emsp;Dano: **1d6**<br>&emsp;Attack/Save: **DEX Save**<br>&emsp;Dmg effect: **fogo**<br></span><span style='color:None;font-size:None'>Essa magia é um truque mágico simples que conjuradores iniciantes usam para praticar. Você cria um dos seguintes efeitos mágicos dentro do alcance:<br>&emsp;• Você cria, instantaneamente, um efeito sensorial inofensivo, como uma [relâmpago] chuva de faíscas, [ar] um sopro de vento, [bardo] notas musicais suaves ou [veneno] um odor estranho.<br>&emsp;•[Fogo] Você, instantaneamente, acende ou apaga uma vela, uma tocha ou uma pequena fogueira.<br>&emsp;•[Terra] Você, instantaneamente, limpa ou suja um objeto de até 1 metro cúbico. Você pode limpar ou sujar uma parte de uma roupa com lama.<br>&emsp;•[Água] Você seca ou molha uma porção de tecido, madeira ou algo do tipo.<br>&emsp;•[Fogo] Você esfria, esquenta ou melhora o sabor de até 1 metro cubico de matéria inorgânica por 1 hora.<br>&emsp;•[Metal] Você faz uma cor, uma pequena marca ou um símbolo aparecer em um objeto ou superfície metálica por 1 hora.<br>&emsp;•[Ilusão] Você cria uma bugiganga não-mágica ou uma imagem ilusória que caiba na sua mão e que dura até o final do seu próximo turno.<br>&emsp;Se você conjurar essa magia diversas vezes, você pode ter até três dos seus efeitos não-instantâneos ativos, ao mesmo tempo, e você pode dissipar um desses efeitos com uma ação.<br></span><span style='color:gray;font-size:10px'>_LDJ_</span>
# <span style='color:None;font-size:None'>**Raio de Gelo _(Ray of Frost)_** - truque<br></span><span style='color:None;font-size:13px'>&emsp;Escola: **elemental** (_água, ar, relâmpago_)<br>&emsp;Tempo conjuração: **1 ação**<br>&emsp;Alcance: **18 metros**<br>&emsp;Componentes: **VS**<br>&emsp;Mana: **150**<br>&emsp;Duração: **instantânea**<br>&emsp;Dano: **1d8**<br>&emsp;Attack/Save: **distância**<br>&emsp;Dmg effect: **elemental**<br></span><span style='color:None;font-size:None'>Um raio elemental parte em direção de uma criatura, dentro do alcance. Realize um ataque à distância com magia contra o alvo. Se atingir, ele sofre 1d8 de dano elemental e seu deslocamento é reduzido em 3 metros até o começo do seu próximo turno.<br>&emsp;O dano da magia aumenta em 1d8 quando você alcança o 5° nível (2d8), 11° nível (3d8) e 17° nível (4d8).<br></span><span style='color:gray;font-size:10px'>_LDJ_</span>
# <span style='color:None;font-size:None'>**Resistência _(Resistence)_** - truque<br></span><span style='color:None;font-size:13px'>&emsp;Escola: **elemental** (_luz, água_)<br>&emsp;Tempo conjuração: **1 ação**<br>&emsp;Alcance: **toque**<br>&emsp;Componentes: **VSM** _(um manto em miniatura)_<br>&emsp;Mana: **75** (_+ 50 por turno_)<br>&emsp;Duração: **concentração, até 1 minuto**<br></span><span style='color:None;font-size:None'>Você toca uma criatura voluntária e uma aura elemental envolve ela, desaparecendo após alguns segundos. Uma vez, antes da magia acabar, o alvo pode rolar 1d4 e adicionar o número rolado a um teste de resistência de sua escolha. Ele pode rolar o dado antes ou depois de realizar o teste de resistência. Após isso, a magia termina. Você gasta 50 de mana por turno até o final da magia.<br></span><span style='color:gray;font-size:10px'>_LDJ_</span>
# <span style='color:None;font-size:None'>**Estabilizar _(Spare the Dying)_** - truque<br></span><span style='color:None;font-size:13px'>&emsp;Escola: **elemental** (_água, luz_)<br>&emsp;Tempo conjuração: **1 ação**<br>&emsp;Alcance: **toque**<br>&emsp;Componentes: **VS**<br>&emsp;Mana: **100**<br>&emsp;Duração: **instantânea**<br></span><span style='color:None;font-size:None'>Você toca uma criatura viva que esteja com 0 pontos de vida. A criatura é estabilizada.<br>&emsp;Essa magia não afeta mortos-vivos ou constructos.<br></span><span style='color:gray;font-size:10px'>_LDJ_</span>
# <span style='color:None;font-size:None'>**Rompante de Espadas _(Sword Burst)_** - truque<br></span><span style='color:None;font-size:13px'>&emsp;Escola: **elemental** (_água, terra, ar, fogo, sombras, luz, metal_)<br>&emsp;Tempo conjuração: **1 ação**<br>&emsp;Alcance: **pessoal**<br>&emsp;Componentes: **VSM** _(um pouco de pó de prata)_<br>&emsp;Mana: **50**<br>&emsp;Duração: **instantânea**<br>&emsp;Dano: **1d6**<br>&emsp;Attack/Save: **DEX Save**<br>&emsp;Dmg effect: **fogo**<br></span><span style='color:None;font-size:None'>Você cria um círculo momentâneo de lâminas elementais que giram ao seu redor. Todas as outras criaturas a até 1,5m de você devem ser bem-sucedidas em uma salvaguarda de Destreza ou recebem 1d6 de dano elemental.<br>&emsp;O dano da magia aumenta em 1d6 quando você alcança o 5º nível (2d6), 11 nível (3d6), e 17º nível (4d6).<br></span><span style='color:gray;font-size:10px'>_Tasha_</span>
